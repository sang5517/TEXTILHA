# %% [markdown]
# <a href="https://colab.research.google.com/github/sang5517/TEXTILHA/blob/master/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_text_ilha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # 판다스 라이브러리 임포트
file_url = 'https://media.githubusercontent.com/media/musthave-ML10/data_source/main/insurance.csv'
data = pd.read_csv(file_url) # 데이터셋 읽기

# %%
# 데이터 상위 5개 확인
data.head()
# Out:
#    age  sex     bmi  children  smoker      charges
# 0   19    0  27.900         0       1  16884.92400
# 1   18    1  33.770         1       0   1725.55230
# 2   28    1  33.000         3       0   4449.46200
# 3   33    1  22.705         0       0  21984.47061
# 4   32    1  28.880         0       0   3866.85520

# %%
# 데이터 메타 정보 확인
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   charges   1338 non-null   float64
# dtypes: float64(2), int64(4)
# memory usage: 62.8 KB

# %%
# 데이터 요약 통계 확인
data.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             charges
# count   1338.000000
# mean   13270.422265
# std    12110.011237
# min     1121.873900
# 25%     4740.287150
# 50%     9382.033000
# 75%    16639.912515
# max    63770.428010

# %%
# 데이터 요약 통계 소수점 2자리로 확인
round(data.describe( ) , 2)
# Out:
#            age      sex      bmi  children  smoker   charges
# count  1338.00  1338.00  1338.00   1338.00  1338.0   1338.00
# mean     39.21     0.51    30.66      1.09     0.2  13270.42
# std      14.05     0.50     6.10      1.21     0.4  12110.01
# min      18.00     0.00    15.96      0.00     0.0   1121.87
# 25%      27.00     0.00    26.30      0.00     0.0   4740.29
# 50%      39.00     1.00    30.40      1.00     0.0   9382.03
# 75%      51.00     1.00    34.69      2.00     0.0  16639.91
# max      64.00     1.00    53.13      5.00     1.0  63770.43

# %%
# 문제1.
# 특성(문제 데이터, 독립변수)와 타겟(정답, 종속변수) 데이터로 나누기

# %%
# 문제2.
# 학습용 데이터와 테스트용 데이터를 학습데이터 8 : 테스트데이터 2 비율로 분리하기

# %%
# 문제3.
# 학습용 데이터를 이용해 선형회귀 모델 학습시키기

# %%
# 문제4
# 테스트 데이터(X_test)를 예측한 결과 출력

# %%
comparison = pd.DataFrame({'actual': y_test, 'pred': pred})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-af203514142e> in <cell line: 1>()
# ----> 1 comparison = pd.DataFrame({'actual': y_test, 'pred': pred})
#
# NameError: name 'y_test' is not defined

# %%
comparison

# %%
import matplotlib.pyplot as plt # ①
import seaborn as sns # ②

# %%
plt.figure(figsize=(10,10)) # ① 그래프 크기 정의
sns.scatterplot(x = 'actual', y = 'pred', data = comparison) # ②
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9da6ff4e4dfa> in <cell line: 2>()
#       1 plt.figure(figsize=(10,10)) # ① 그래프 크기 정의
# ----> 2 sns.scatterplot(x = 'actual', y = 'pred', data = comparison) # ②
#
# NameError: name 'comparison' is not defined

# %%
from sklearn.metrics import mean_squared_error # ① MSE 라이브러리 임포트
mean_squared_error(y_test, pred) ** 0.5 # ② RMSE 계산 실행
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-80ef03861c3f> in <cell line: 2>()
#       1 from sklearn.metrics import mean_squared_error # ① MSE 라이브러리 임포트
# ----> 2 mean_squared_error(y_test, pred) ** 0.5 # ② RMSE 계산 실행
#
# NameError: name 'y_test' is not defined
